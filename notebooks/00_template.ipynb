# %% [markdown]
# # Notebook Template
#
# Use this structure for MSE446 nanoparticle ordering analysis notebooks.

# %% [markdown]
# ## 1. Project setup

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

# %% [markdown]
# ## 2. Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## 3. Paths and configuration

# %%
from src.config import ensure_output_dirs, get_image_dir, DATA_DIR, RESULTS_DIR, FIGURES_DIR

ensure_output_dirs()
IMAGE_DIR = get_image_dir()
IMAGE_DIR
# Out:
# PosixPath('/home/jp/MSE446_Nanoparticle_Ordering/data/flat_with_kv_mm_filenames_cropped')

# %% [markdown]
# ## 4. Load metadata

# %%
# Load or build metadata here.

# %% [markdown]
# ## 5. Sanity checks

# %%
# Add checks for row counts, labels, missing paths, and leakage groups.

# %% [markdown]
# ## 6. Main analysis

# %%
# Main analysis code goes here.

# %% [markdown]
# ## 7. Results/figures

# %%
# Save figures to results/figures/.

# %% [markdown]
# ## 8. Notes for report
#
# - Key observations:
# - Assumptions:
# - Follow-up checks:
